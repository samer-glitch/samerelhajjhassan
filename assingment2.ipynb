# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics
import math
step = 0.01
ksi5=0.282828282828
ksi6=8
ksi7=0.717171717171
ksi8=5

y=np.arange(-10,10,step)
x=ksi5*(math.e**(-ksi6*(y*y)))+ksi7*(math.e**(-ksi8*(y*y)))
plt.plot(y,x)
plt.show()
