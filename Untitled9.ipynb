# %%
import numpy as np
import matplotlib.pyplot as plt

observations = [303, 125, 31, 31, 140]

def likelihood(theta):
    likelihood_val = 1
    for obs in observations:
        likelihood_val *= (-obs / (theta**2)) + (2 / theta)
    return likelihood_val

theta_values = np.linspace(0.01, 100, 10000)  # Range of theta values to evaluate

likelihood_values = [likelihood(theta) for theta in theta_values]

max_likelihood = max(likelihood_values)
max_likelihood_index = np.argmax(likelihood_values)
mle_theta = theta_values[max_likelihood_index]

plt.plot(theta_values, likelihood_values)
plt.scatter(mle_theta, max_likelihood, color='red', label='MLE')
plt.xlabel('θ')
plt.ylabel('Likelihood')
plt.title('Likelihood Function')
plt.legend()

plt.show()

print("Maximum Likelihood:", max_likelihood)
print("MLE for θ:", mle_theta)
# Out:
# Maximum Likelihood: 6.393583207499611e-11
# MLE for θ: 65.42

# %%
import sympy as sp

observations = [303, 125, 31, 31, 140]
theta = sp.symbols('theta', positive=True)

# Define the log-likelihood function
def log_likelihood(theta):
    log_likelihood_val = 0
    for obs in observations:
        log_likelihood_val += sp.log((-obs / (theta ** 2)) + (2 / theta))
    return log_likelihood_val

# Calculate the derivative of the log-likelihood function with respect to theta
log_likelihood_derivative = sp.diff(log_likelihood(theta), theta)

# Solve for the maximum likelihood estimator (MLE)
mle_solutions = sp.solve(log_likelihood_derivative, theta)

# Select the positive MLE value
mle_theta = max([sol.evalf() for sol in mle_solutions if sol > 0])

print("MLE for θ:", mle_theta)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 20>()
#      17 mle_solutions = sp.solve(log_likelihood_derivative, theta)
#      19 # Select the positive MLE value
# ---> 20 mle_theta = max([sol.evalf() for sol in mle_solutions if sol > 0])
#      22 print("MLE for θ:", mle_theta)
#
# Input In [10], in <listcomp>(.0)
#      17 mle_solutions = sp.solve(log_likelihood_derivative, theta)
#      19 # Select the positive MLE value
# ---> 20 mle_theta = max([sol.evalf() for sol in mle_solutions if sol > 0])
#      22 print("MLE for θ:", mle_theta)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\relational.py:511, in Relational.__bool__(self)
#     510 def __bool__(self):
# --> 511     raise TypeError("cannot determine truth value of Relational")
#
# TypeError: cannot determine truth value of Relational

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

n = 10
sample_mean = 805.4
sample_std = 16.36
null_mean = 811

degrees_of_freedom = n - 1
t = (sample_mean - null_mean) / (sample_std / np.sqrt(n))

x = np.linspace(-4, 4, 500)
y = stats.t.pdf(x, df=degrees_of_freedom)

plt.plot(x, y, 'b-', label='t-Distribution')
plt.fill_between(x[x <= t], y[x <= t], 0, color='red', alpha=0.8, label='p-value')
plt.xlabel('t')
plt.ylabel('Probability Density')
plt.title('t-Distribution with p-value')
plt.legend()
plt.show()

# %%
import numpy as np
from scipy import stats

# Sample data
weights = np.array([757, 755, 819, 685, 801, 861, 836, 860, 808, 852])

# Null hypothesis: μ >= 811
# Alternative hypothesis: μ < 811

# Set the significance level (α)
alpha = 0.05

# Calculate the sample statistics
sample_mean = np.mean(weights)
sample_std = np.std(weights, ddof=1)  # ddof=1 for sample standard deviation
sample_size = len(weights)

# Calculate the test statistic (t)
null_mean = 811
standard_error = sample_std / np.sqrt(sample_size)
t_statistic = (sample_mean - null_mean) / standard_error

# Calculate the critical t-value
critical_value = stats.t.ppf(alpha, df=sample_size - 1)

# Make a decision
if t_statistic < critical_value:
    conclusion = "Reject the null hypothesis"
else:
    conclusion = "Fail to reject the null hypothesis"

# Draw the conclusion
print("Sample Mean:", sample_mean)
print("Sample Standard Deviation:", sample_std)
print("Test Statistic (t):", t_statistic)
print("Critical Value:", critical_value)
print("Conclusion:", conclusion)
# Out:
# Sample Mean: 803.4
# Sample Standard Deviation: 56.50014749243285
# Test Statistic (t): -0.42536721201477523
# Critical Value: -1.8331129326536337
# Conclusion: Fail to reject the null hypothesis

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Sample data
weights = np.array([757, 755, 819, 685, 801, 861, 836, 860, 808, 852])

# Null hypothesis: μ >= 811
# Alternative hypothesis: μ < 811

# Set the significance level (α)
alpha = 0.05

# Calculate the sample statistics
sample_mean = np.mean(weights)
sample_std = np.std(weights, ddof=1)  # ddof=1 for sample standard deviation
sample_size = len(weights)

# Calculate the critical value for H₀ and Hₐ
critical_value = stats.t.ppf(1 - alpha, df=sample_size - 1)

# Generate x values for plotting
x = np.linspace(750, 870, 1000)

# Calculate the normal distribution
y = stats.norm.pdf(x, loc=sample_mean, scale=sample_std/np.sqrt(sample_size))

# Plot the normal distribution
plt.plot(x, y, label='Normal Distribution')

# Plot the null hypothesis (H₀) region
plt.fill_between(x, y, where=x >= null_mean, color='blue', alpha=0.3, label='Null Hypothesis (H₀)')

# Plot the alternative hypothesis (Hₐ) region
plt.fill_between(x, y, where=x < null_mean, color='red', alpha=0.3, label='Alternative Hypothesis (Hₐ)')

# Plot the sample mean
plt.axvline(x=sample_mean, color='black', linestyle='--', label='Sample Mean')

# Add labels and title
plt.xlabel('Weight (g)')
plt.ylabel('Probability Density')
plt.title('Distribution of Hammer Weights')

# Add legend
plt.legend()

# Calculate the test statistic (t)
standard_error = sample_std / np.sqrt(sample_size)
t_statistic = (sample_mean - null_mean) / standard_error

# Calculate the p-value
p_value = stats.t.cdf(t_statistic, df=sample_size - 1)

# Display the test statistic and p-value
plt.text(750, 0.04, f'Test Statistic (t): {t_statistic:.2f}', fontsize=12)
plt.text(750, 0.03, f'p-value: {p_value:.4f}', fontsize=12)

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Sample data
weights = np.array([757, 755, 819, 685, 801, 861, 836, 860, 808, 852])

# Null hypothesis: μ >= 811
# Alternative hypothesis: μ < 811

# Set the significance level (α)
alpha = 0.05

# Calculate the sample statistics
sample_mean = np.mean(weights)
sample_std = np.std(weights, ddof=1)  # ddof=1 for sample standard deviation
sample_size = len(weights)

# Calculate the critical value for one-tailed test
critical_value = stats.t.ppf(alpha, df=sample_size - 1)

# Calculate the p-value for one-tailed test
t_statistic, p_value = stats.ttest_1samp(weights, popmean=811)

# Generate x values for plotting
x = np.linspace(750, 900, 1000)

# Calculate the normal distribution
y = stats.norm.pdf(x, loc=sample_mean, scale=sample_std / np.sqrt(sample_size))

# Plot the normal distribution
plt.plot(x, y, label='Normal Distribution')

# Plot the null hypothesis (H₀) and alternative hypothesis (Hₐ) regions
plt.fill_between(x, 0, y, where=x >= null_mean, color='blue', alpha=0.2, label='Null Hypothesis (H₀)')
plt.fill_between(x, 0, y, where=x < null_mean, color='red', alpha=0.2, label='Alternative Hypothesis (Hₐ)')

# Add labels and title
plt.xlabel('Weight (g)')
plt.ylabel('Probability Density')
plt.title('Distribution of Hammer Weights')

# Add legend
plt.legend()

# Display the test statistic and p-value
plt.text(760, 0.015, f'Test Statistic (t): {t_statistic:.2f}', fontsize=10)
plt.text(760, 0.012, f'p-value: {p_value:.3f}', fontsize=10)

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Sample data
weights = np.array([757, 755, 819, 685, 801, 861, 836, 860, 808, 852])

# Null hypothesis: μ >= 811
# Alternative hypothesis: μ < 811

# Set the significance level (α)
alpha = 0.05

# Calculate the sample statistics
sample_mean = np.mean(weights)
sample_std = np.std(weights, ddof=1)  # ddof=1 for sample standard deviation
sample_size = len(weights)

# Calculate the test statistic and p-value for one-tailed test
t_statistic, p_value = stats.ttest_1samp(weights, popmean=811, alternative='less')

# Calculate the critical value for one-tailed test
critical_value = stats.t.ppf(alpha, df=sample_size - 1)

# Generate x values for plotting
x = np.linspace(750, 900, 1000)

# Calculate the normal distribution
y = stats.norm.pdf(x, loc=sample_mean, scale=sample_std / np.sqrt(sample_size))

# Plot the normal distribution
plt.plot(x, y, label='Normal Distribution')

# Plot the null hypothesis (H₀) and alternative hypothesis (Hₐ) regions
plt.fill_between(x, 0, y, where=x >= null_mean, color='blue', alpha=0.2, label='Null Hypothesis (H₀)')
plt.fill_between(x, 0, y, where=x < null_mean, color='red', alpha=0.2, label='Alternative Hypothesis (Hₐ)')

# Plot the test result
if t_statistic < critical_value:
    plt.axvline(x=critical_value, color='green', linestyle='--', label='Test Result: Reject H₀')
else:
    plt.axvline(x=critical_value, color='green', linestyle='--', label='Test Result: Fail to Reject H₀')

# Add labels and title
plt.xlabel('Weight (g)')
plt.ylabel('Probability Density')
plt.title('Distribution of Hammer Weights')

# Add legend
plt.legend()

# Display the test statistic, p-value, and conclusion
if t_statistic < critical_value:
    conclusion = "Reject the null hypothesis"
else:
    conclusion = "Fail to reject the null hypothesis"

plt.text(760, 0.015, f'Test Statistic (t): {t_statistic:.2f}', fontsize=10)
plt.text(760, 0.012, f'p-value: {p_value:.4f}', fontsize=10)
plt.text(760, 0.009, f'Conclusion: {conclusion}', fontsize=10)

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Sample data
weights = np.array([757, 755, 819, 685, 801, 861, 836, 860, 808, 852])

# Null hypothesis: μ >= 811
# Alternative hypothesis: μ < 811

# Set the significance level (α)
alpha = 0.05

# Calculate the sample statistics
sample_mean = np.mean(weights)
sample_std = np.std(weights, ddof=1)  # ddof=1 for sample standard deviation
sample_size = len(weights)

# Calculate the critical value for one-tailed test
critical_value = stats.t.ppf(alpha, df=sample_size - 1)

# Generate x values for plotting
x = np.linspace(750, 900, 1000)

# Calculate the normal distribution
y = stats.norm.pdf(x, loc=sample_mean, scale=sample_std / np.sqrt(sample_size))

# Plot the normal distribution
plt.plot(x, y, label='Normal Distribution')

# Plot the null hypothesis (H₀) and alternative hypothesis (Hₐ) regions
plt.fill_between(x, 0, y, where=x >= null_mean, color='blue', alpha=0.2, label='Null Hypothesis (H₀)')
plt.fill_between(x, 0, y, where=x < null_mean, color='red', alpha=0.2, label='Alternative Hypothesis (Hₐ)')

# Add labels and title
plt.xlabel('Weight (g)')
plt.ylabel('Probability Density')
plt.title('Distribution of Hammer Weights')

# Add legend
plt.legend()

# Plot the critical region for the null hypothesis
plt.fill_between(x, 0, y, where=x < critical_value, color='gray', alpha=0.3, label='Critical Region (H₀)')

# Plot the critical region for the alternative hypothesis
plt.fill_between(x, 0, y, where=x >= critical_value, color='orange', alpha=0.3, label='Critical Region (Hₐ)')

# Add labels for error probabilities
plt.text(760, 0.017, f'Type I Error (α): {alpha:.2f}', fontsize=10)
plt.text(760, 0.014, f'Type II Error (β): {1 - alpha:.2f}', fontsize=10)

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Sample data
weights = np.array([757, 755, 819, 685, 801, 861, 836, 860, 808, 852])

# Null hypothesis: μ >= 811
# Alternative hypothesis: μ < 811

# Set the significance level (α)
alpha = 0.05

# Calculate the sample statistics
sample_mean = np.mean(weights)
sample_std = np.std(weights, ddof=1)  # ddof=1 for sample standard deviation
sample_size = len(weights)

# Calculate the critical value for one-tailed test
critical_value = stats.t.ppf(alpha, df=sample_size - 1)

# Generate x values for plotting
x = np.linspace(750, 900, 1000)

# Calculate the normal distribution
y = stats.norm.pdf(x, loc=sample_mean, scale=sample_std / np.sqrt(sample_size))

# Plot the normal distribution
plt.plot(x, y, label='Normal Distribution')

# Plot the null hypothesis (H₀) and alternative hypothesis (Hₐ) regions
plt.fill_between(x, 0, y, where=x >= null_mean, color='blue', alpha=0.2, label='Null Hypothesis (H₀)')
plt.fill_between(x, 0, y, where=x < null_mean, color='red', alpha=0.2, label='Alternative Hypothesis (Hₐ)')

# Plot the critical region for Type I error (α)
plt.fill_between(x, 0, y, where=x < critical_value, color='green', alpha=0.2, label='Type I Error (α)')

# Plot the acceptance region
plt.fill_between(x, 0, y, where=x >= critical_value, color='yellow', alpha=0.2, label='Acceptance Region')

# Add labels and title
plt.xlabel('Weight (g)')
plt.ylabel('Probability Density')
plt.title('Distribution of Hammer Weights')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Sample data
weights = np.array([757, 755, 819, 685, 801, 861, 836, 860, 808, 852])

# Null hypothesis: μ >= 811
# Alternative hypothesis: μ < 811

# Set the significance level (α)
alpha = 0.05

# Calculate the sample statistics
sample_mean = np.mean(weights)
sample_std = np.std(weights, ddof=1)  # ddof=1 for sample standard deviation
sample_size = len(weights)

# Calculate the critical value for one-tailed test
critical_value = stats.t.ppf(alpha, df=sample_size - 1)

# Generate x values for plotting
x = np.linspace(750, 900, 1000)

# Calculate the normal distribution
y = stats.norm.pdf(x, loc=sample_mean, scale=sample_std / np.sqrt(sample_size))

# Plot the normal distribution
plt.plot(x, y, label='Normal Distribution')

# Plot the null hypothesis (H₀) and alternative hypothesis (Hₐ) regions
plt.fill_between(x, 0, y, where=x >= sample_mean, color='blue', alpha=0.2, label='Null Hypothesis (H₀)')
plt.fill_between(x, 0, y, where=x < sample_mean, color='red', alpha=0.2, label='Alternative Hypothesis (Hₐ)')

# Plot the critical region for Type I error (α)
plt.fill_between(x, 0, y, where=x < critical_value, color='green', alpha=0.2, label='Type I Error (α)')

# Plot the acceptance region
plt.fill_between(x, 0, y, where=x >= critical_value, color='yellow', alpha=0.2, label='Acceptance Region')

# Add labels and title
plt.xlabel('Weight (g)')
plt.ylabel('Probability Density')
plt.title('Distribution of Hammer Weights')

# Add legend
plt.legend()

# Add text for error probabilities
plt.text(770, 0.008, 'Type I Error (α)', fontsize=10, color='green')
plt.text(840, 0.008, 'Acceptance Region', fontsize=10, color='yellow')

# Display the plot
plt.show()

# %%
from scipy.stats import f
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (
    MultipleLocator, 
    StrMethodFormatter
)
#921,881,888,897,877,868,886,930,904,885
dfn, dfd = 999, 9
f_sample = 4.0519
alpha = [0.05, 0.025, f.sf(f_sample, dfn, dfd), 0.01, 0.005, 0.0025, 0.001]
df = pd.DataFrame(
    alpha, 
    columns=["Significance level"]
)
df["Critical value"] = df["Significance level"].apply(
    lambda x: f"{f.ppf(1-x, dfn, dfd):.4f}"
)
df["Type II Error for s = 2\u03C3"] = df["Critical value"].apply(
    lambda x: f"{f.cdf(float(x)/4, dfn, dfd):.4f}"
)
df["Emphasis on sample variance"] = df["Critical value"].apply(
    lambda x: f"{1/float(x):.2%} of \u03C3^2"
)
df["Emphasis on sample standard deviation"] = df["Critical value"].apply(
    lambda x: f"{1/(float(x) ** .5):.2%} of \u03C3"
)
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
x = np.linspace(
    f.ppf(0.00, dfn, dfd),
    f.ppf(0.995, dfn, dfd), 
    100
)
y = f.pdf(x, dfn, dfd)
ax.plot(x, y, 'r-', lw=4, alpha=0.6, label='f pdf')
alpha = f.ppf(1-.05, dfn, dfd)
ax.vlines(alpha, 0, f.pdf(alpha, dfn, dfd), colors='r', lw=2, alpha=0.6, label='_f_0.05')
ax.vlines(1, 0, f.pdf(1, dfn, dfd), colors='r', ls='--', lw=2, alpha=0.6, label='_f_0.05')
ax.fill_between(np.arange(alpha, x[-1], .1), f.pdf(np.arange(alpha, x[-1], .1), dfn, dfd), color='r', alpha=0.2)
ax.fill_between(np.arange(1, alpha, .1), f.pdf(np.arange(1, alpha, .1), dfn, dfd), color='g', alpha=0.1)
ax.fill_between(np.arange(0, 1.1, .1), f.pdf(np.arange(0, 1.1, .1), dfn, dfd), color='b', alpha=0.1)
ax.annotate(
    fr"$(f_{{critical}}={alpha:.5g}, \alpha=0.05, \beta=0.95)$", 
    xy=(alpha, 0.05),  
    xycoords='data',
    xytext=(alpha * 0.85, 0.15), 
    textcoords='data',
    fontsize=12
)
ax.annotate(
    fr"$(f_0=1, \alpha={f.sf(1, dfn, dfd):.5g}, \beta={f.cdf(1, dfn, dfd):.5g})$", 
    xy=(1, .9),  
    xycoords='data',
    xytext=(0.85, 0.95), 
    textcoords='data',
    fontsize=12
)
ax.annotate(
    '$H_a$', 
    xy=(.7, y.max() / 2),  
    xycoords='data',
    xytext=(1.5, .75), 
    textcoords='data',
    arrowprops=dict(facecolor='b', edgecolor='b', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="b")
)
ax.annotate(
    '$H_0$', 
    xy=(1.2, y.max() / 4),  
    xycoords='data',
    xytext=(2.5, .7), 
    textcoords='data',
    arrowprops=dict(facecolor='g', edgecolor='g', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="g")
)
ax.arrow(1.05, .025, alpha - 1.2,  0, width=.005, head_width=.025, head_length=.1, fc='r', ec='r', alpha=.6)
ax.set_title(f'Probability densitity function for $f \sim F(999,9)$', fontsize=16)
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:.0%}'))
ax.xaxis.set_minor_locator(MultipleLocator(.25))
ax.set(xlim=(0, x[-1]), ylim=(0, 1), autoscale_on=False)
ax.set_xlabel('F-test-statistic $f$', fontsize=14)
ax.set_ylabel('Probability density', fontsize=14)
fig.tight_layout()
fig.savefig("4.svg", bbox_inches="tight")
plt.show()
df
# Out:
#    Significance level Critical value Type II Error for s = 2σ  \
# 0            0.050000         2.7116                   0.1523
# 1            0.025000         3.3400                   0.2926
# 2            0.012641         4.0519                   0.4488
# 3            0.010000         4.3211                   0.5017
# 4            0.005000         5.2012                   0.6453
# 5            0.002500         6.2235                   0.7609
# 6            0.001000         7.8357                   0.8677
#
#   Emphasis on sample variance Emphasis on sample standard deviation
# 0               36.88% of σ^2                           60.73% of σ
# 1               29.94% of σ^2                           54.72% of σ
# 2               24.68% of σ^2                           49.68% of σ
# 3               23.14% of σ^2                           48.11% of σ
# 4               19.23% of σ^2                           43.85% of σ
# ...

# %%
import statistics

sample = [757, 755, 819, 685, 801, 861, 836, 860, 808, 852]

mean = statistics.mean(sample)
std_dev = statistics.stdev(sample)

print("Mean:", mean)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 803.4
# Standard Deviation: 56.50014749243285

# %%
import math

# Sample data
sample = [757, 755, 819, 685, 801, 861, 836, 860, 808, 852]
sample_mean = statistics.mean(sample)
sample_std_dev = statistics.stdev(sample)
sample_size = len(sample)

# Population mean (μ)
population_mean = 800

# Calculate the t-value
t_value = (sample_mean - population_mean) / (sample_std_dev / math.sqrt(sample_size))

print("t-value:", t_value)
# Out:
# t-value: 0.19029585800660814

# %%
from scipy.stats import f
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (
    MultipleLocator, 
    StrMethodFormatter
)

dfn, dfd = 999, 9
f_sample = 1.8892357852354515
alpha = [f.sf(f_sample, dfn, dfd), 0.05, 0.025,  0.01, 0.005, 0.0025, 0.001]
df = pd.DataFrame(
    alpha, 
    columns=["Significance level"]
)
df["Critical value"] = df["Significance level"].apply(
    lambda x: f"{f.ppf(x, dfn, dfd):.4f}"
)
df["Type II Error for s = 2\u03C3"] = df["Critical value"].apply(
    lambda x: f"{f.cdf(float(x)/4, dfn, dfd):.4f}"
)
df["Emphasis on sample variance"] = df["Critical value"].apply(
    lambda x: f"{1/float(x):.2%} of \u03C3^2"
)
df["Emphasis on sample standard deviation"] = df["Critical value"].apply(
    lambda x: f"{1/(float(x) ** .5):.2%} of \u03C3"
)
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
x = np.linspace(
    f.ppf(0.00, dfn, dfd),
    f.ppf(0.995, dfn, dfd), 
    100
)
y = f.pdf(x, dfn, dfd)
ax.plot(x, y, 'r-', lw=4, alpha=0.6, label='f pdf')
alpha = f.ppf(1-.05, dfn, dfd)
ax.vlines(alpha, 0, f.pdf(alpha, dfn, dfd), colors='r', lw=2, alpha=0.6, label='_f_0.05')
ax.vlines(1, 0, f.pdf(1, dfn, dfd), colors='r', ls='--', lw=2, alpha=0.6, label='_f_0.05')
ax.fill_between(np.arange(alpha, x[-1], .1), f.pdf(np.arange(alpha, x[-1], .1), dfn, dfd), color='r', alpha=0.2)
ax.fill_between(np.arange(1, alpha, .1), f.pdf(np.arange(1, alpha, .1), dfn, dfd), color='g', alpha=0.1)
ax.fill_between(np.arange(0, 1.1, .1), f.pdf(np.arange(0, 1.1, .1), dfn, dfd), color='b', alpha=0.1)
ax.annotate(
    fr"$(f_{{critical}}={alpha:.5g}, \alpha=0.05, \beta=0.95)$", 
    xy=(alpha, 0.05),  
    xycoords='data',
    xytext=(alpha * 0.85, 0.15), 
    textcoords='data',
    fontsize=12
)
ax.annotate(
    fr"$(f_0=1, \alpha={f.sf(1, dfn, dfd):.5g}, \beta={f.cdf(1, dfn, dfd):.5g})$", 
    xy=(1, .9),  
    xycoords='data',
    xytext=(0.85, 0.95), 
    textcoords='data',
    fontsize=12
)
ax.annotate(
    '$H_a$', 
    xy=(.7, y.max() / 2),  
    xycoords='data',
    xytext=(1.5, .75), 
    textcoords='data',
    arrowprops=dict(facecolor='b', edgecolor='b', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="b")
)
ax.annotate(
    '$H_0$', 
    xy=(1.2, y.max() / 4),  
    xycoords='data',
    xytext=(2.5, .7), 
    textcoords='data',
    arrowprops=dict(facecolor='g', edgecolor='g', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="g")
)
ax.arrow(1.05, .025, alpha - 1.2,  0, width=.005, head_width=.025, head_length=.1, fc='r', ec='r', alpha=.6)
ax.set_title(f'Probability densitity function for $f \sim F(999,9)$', fontsize=16)
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:.0%}'))
ax.xaxis.set_minor_locator(MultipleLocator(.25))
ax.set(xlim=(0, x[-1]), ylim=(0, 1), autoscale_on=False)
ax.set_xlabel('F-test-statistic $f$', fontsize=14)
ax.set_ylabel('Probability density', fontsize=14)
fig.tight_layout()
fig.savefig("4.svg", bbox_inches="tight")
plt.show()
df
# Out:
#    Significance level Critical value Type II Error for s = 2σ  \
# 0            0.146049         0.6704                   0.0000
# 1            0.050000         0.5293                   0.0000
# 2            0.025000         0.4703                   0.0000
# 3            0.010000         0.4124                   0.0000
# 4            0.005000         0.3784                   0.0000
# 5            0.002500         0.3502                   0.0000
# 6            0.001000         0.3195                   0.0000
#
#   Emphasis on sample variance Emphasis on sample standard deviation
# 0              149.16% of σ^2                          122.13% of σ
# 1              188.93% of σ^2                          137.45% of σ
# 2              212.63% of σ^2                          145.82% of σ
# 3              242.48% of σ^2                          155.72% of σ
# 4              264.27% of σ^2                          162.56% of σ
# ...

# %%
from scipy.stats import f
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (
    MultipleLocator, 
    StrMethodFormatter
)

dfn, dfd = 9, 999
f_sample = 0.0723
alpha = [f.cdf(f_sample, dfn, dfd), 0.05]
df = pd.DataFrame(
    alpha, 
    columns=["Significance level"]
)
df["Critical value"] = df["Significance level"].apply(
    lambda x: f"{f.ppf(x, dfn, dfd):.4f}"
)
df["Emphasis on sample variance"] = df["Critical value"].apply(
    lambda x: f"{1/float(x):.2%} of 𝜎^2"
)
df["Emphasis on sample standard deviation"] = df["Critical value"].apply(
    lambda x: f"{1/(float(x) ** .5):.2%} of 𝜎"
)

fig, ax = plt.subplots(1, 1, figsize=(8, 5))
x = np.linspace(
    0,
    f.ppf(0.995, dfn, dfd), 
    100
)
y = f.pdf(x, dfn, dfd)
ax.plot(x, y, 'r-', lw=4, alpha=0.6, label='f pdf')
alpha = f.ppf(0.05, dfn, dfd)
ax.vlines(alpha, 0, f.pdf(alpha, dfn, dfd), colors='r', lw=2, alpha=0.6, label='_f_0.05')
ax.fill_between(np.arange(0, alpha, .1), f.pdf(np.arange(0, alpha, .1), dfn, dfd), color='r', alpha=0.2)
ax.fill_between(np.arange(alpha, x[-1], .1), f.pdf(np.arange(alpha, x[-1], .1), dfn, dfd), color='g', alpha=0.1)
ax.annotate(
    fr"$(f_{{critical}}={alpha:.5g}, \alpha=0.05)$", 
    xy=(alpha, 0.02),  
    xycoords='data',
    xytext=(alpha * 0.85, 0.05), 
    textcoords='data',
    fontsize=12
)
ax.annotate(
    '$H_a$', 
    xy=(alpha * 0.7, y.max() / 2),  
    xycoords='data',
    xytext=(alpha * 1.5, .07), 
    textcoords='data',
    arrowprops=dict(facecolor='g', edgecolor='g', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="g")
)
ax.annotate(
    '$H_0$', 
    xy=(alpha * 1.2, y.max() / 4),  
    xycoords='data',
    xytext=(alpha * 2.5, .06), 
    textcoords='data',
    arrowprops=dict(facecolor='r', edgecolor='r', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="r")
)
ax.arrow(0.07, .015, alpha - 0.08,  0, width=.005, head_width=.025, head_length=.1, fc='r', ec='r', alpha=.6)
ax.set_title(f'Probability density function for $f \sim F(9, 999)$', fontsize=16)
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:.0%}'))
ax.xaxis.set_minor_locator(MultipleLocator(.25))
ax.set(xlim=(0, x[-1]), ylim=(0, 0.1), autoscale_on=False)
ax.set_xlabel('F-test-statistic $f$', fontsize=14)
ax.set_ylabel('Probability density', fontsize=14)
fig.tight_layout()
plt.show()
df
# Out:
#    Significance level Critical value Emphasis on sample variance  \
# 0            0.000095         0.0723             1383.13% of 𝜎^2
# 1            0.050000         0.3688              271.15% of 𝜎^2
#
#   Emphasis on sample standard deviation
# 0                          371.90% of 𝜎
# 1                          164.67% of 𝜎

# %%
from scipy.stats import f
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (
    MultipleLocator, 
    StrMethodFormatter
)

dfn, dfd = 9, 999
f_sample = 1.8892357852354515
alpha = [f.cdf(f_sample, dfn, dfd), 0.05]
df = pd.DataFrame(
    alpha, 
    columns=["Significance level"]
)
df["Critical value"] = df["Significance level"].apply(
    lambda x: f"{f.ppf(x, dfn, dfd):.4f}"
)
df["Emphasis on sample variance"] = df["Critical value"].apply(
    lambda x: f"{1/float(x):.2%} of 𝜎^2"
)
df["Emphasis on sample standard deviation"] = df["Critical value"].apply(
    lambda x: f"{1/(float(x) ** .5):.2%} of 𝜎"
)

fig, ax = plt.subplots(1, 1, figsize=(8, 5))
x = np.linspace(
    0,
    f.ppf(0.995, dfn, dfd), 
    100
)
y = f.pdf(x, dfn, dfd)
ax.plot(x, y, 'r-', lw=2, alpha=0.6, label='F-distribution')
alpha = f.ppf(0.05, dfn, dfd)
ax.fill_between(np.arange(0, alpha, .01), f.pdf(np.arange(0, alpha, .01), dfn, dfd), color='r', alpha=0.2)
ax.fill_between(np.arange(alpha, x[-1], .01), f.pdf(np.arange(alpha, x[-1], .01), dfn, dfd), color='g', alpha=0.1)
ax.annotate(
    fr"$(f_{{critical}}={alpha:.5g}, \alpha=0.05)$", 
    xy=(alpha, 0.004),  
    xycoords='data',
    xytext=(alpha * 0.85, 0.007), 
    textcoords='data',
    fontsize=12
)
ax.annotate(
    '$H_a$', 
    xy=(alpha * 0.7, y.max() / 2),  
    xycoords='data',
    xytext=(alpha * 1.5, .007), 
    textcoords='data',
    arrowprops=dict(facecolor='g', edgecolor='g', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="g")
)
ax.annotate(
    '$H_0$', 
    xy=(alpha * 1.2, y.max() / 4),  
    xycoords='data',
    xytext=(alpha * 2.5, .006), 
    textcoords='data',
    arrowprops=dict(facecolor='r', edgecolor='r', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="r")
)
ax.arrow(0.07, .002, alpha - 0.08,  0, width=.001, head_width=.0025, head_length=.01, fc='r', ec='r', alpha=.6)
ax.set_title(f'Probability density function for F-distribution (dfn=9, dfd=999)', fontsize=16)
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:.3f}'))
ax.xaxis.set_minor_locator(MultipleLocator(.1))
ax.set(xlim=(0, x[-1]), ylim=(0, 0.01), autoscale_on=False)
ax.set_xlabel('F-test-statistic f', fontsize=14)
ax.set_ylabel('Probability density', fontsize=14)
fig.tight_layout()
plt.show()
df
# Out:
#    Significance level Critical value Emphasis on sample variance  \
# 0                0.95         1.8892               52.93% of 𝜎^2
# 1                0.05         0.3688              271.15% of 𝜎^2
#
#   Emphasis on sample standard deviation
# 0                           72.75% of 𝜎
# 1                          164.67% of 𝜎

# %%
from scipy.stats import f
import numpy as np
import matplotlib.pyplot as plt

dfn, dfd = 9, 999
alpha = [0.01, 0.05, 0.1]

fig, ax = plt.subplots(1, 1, figsize=(8, 5))
x = np.linspace(
    0,
    f.ppf(0.995, dfn, dfd), 
    100
)
y = f.pdf(x, dfn, dfd)
ax.plot(x, y, 'r-', lw=2, alpha=0.6, label='f pdf')

for a in alpha:
    crit_value = f.ppf(a, dfn, dfd)
    ax.vlines(crit_value, 0, f.pdf(crit_value, dfn, dfd), colors='r', lw=1, alpha=0.6, label=f'α={a}')
    ax.fill_between(np.arange(0, crit_value, .1), f.pdf(np.arange(0, crit_value, .1), dfn, dfd), alpha=0.2)

ax.legend()
ax.set_title(f'Probability density function for $f \sim F(9, 999)$', fontsize=16)
ax.set_xlabel('F-test-statistic $f$', fontsize=14)
ax.set_ylabel('Probability density', fontsize=14)
plt.show()

# %%
from scipy.stats import f
import numpy as np
import matplotlib.pyplot as plt

dfn, dfd = 9, 999
alpha = [0.01, 0.05, 0.1]

fig, ax = plt.subplots(1, 1, figsize=(8, 5))
x = np.linspace(
    0,
    f.ppf(0.995, dfn, dfd), 
    100
)
y = f.pdf(x, dfn, dfd)
ax.plot(x, y, 'r-', lw=2, alpha=0.6, label='f pdf')

for a in alpha:
    crit_value = f.ppf(a, dfn, dfd)
    ax.vlines(crit_value, 0, f.pdf(crit_value, dfn, dfd), colors='r', lw=1, alpha=0.6, label=f'α={a}')
    ax.fill_between(np.arange(0, crit_value, .1), f.pdf(np.arange(0, crit_value, .1), dfn, dfd), alpha=0.2)

ax.annotate(
    'Reject $H_0$\n(New system makes lower weights)', 
    xy=(3, 0.03),  
    xycoords='data',
    xytext=(3, 0.045), 
    textcoords='data',
    arrowprops=dict(facecolor='b', edgecolor='b', width=1, headwidth=8, alpha=.6),
    horizontalalignment='center', 
    verticalalignment='top',
    fontsize=12,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="b")
)

ax.annotate(
    'Fail to reject $H_0$\n(New system does not make lower weights)', 
    xy=(8, 0.03),  
    xycoords='data',
    xytext=(8, 0.045), 
    textcoords='data',
    arrowprops=dict(facecolor='g', edgecolor='g', width=1, headwidth=8, alpha=.6),
    horizontalalignment='center', 
    verticalalignment='top',
    fontsize=12,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="g")
)

ax.legend()
ax.set_title(f'Probability density function for $f \sim F(9, 999)$', fontsize=16)
ax.set_xlabel('F-test-statistic $f$', fontsize=14)
ax.set_ylabel('Probability density', fontsize=14)
plt.show()

# %%
import scipy.stats as stats
import numpy as np

# Sample weights
weights = [757, 755, 819, 685, 801, 861, 836, 860, 808, 852]

# Population parameters
pop_mean = 811
pop_std = 15.2

# Calculate sample statistics
n = len(weights)
sample_mean = np.mean(weights)
sample_std = np.std(weights, ddof=1)

# Calculate F-test statistic
f_sample = (sample_std ** 2) / (pop_std ** 2)

# Degrees of freedom
dfn = n - 1  # Numerator degrees of freedom
dfd = 999    # Denominator degrees of freedom

# Calculate F-critical value
alpha = 0.05
fcritical = stats.f.ppf(1 - alpha, dfn, dfd)

print("F-sample:", f_sample)
print("F-critical:", fcritical)
# Out:
# F-sample: 13.816943674976915
# F-critical: 1.8892357852354515

# %%
from scipy.stats import f
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (
    MultipleLocator, 
    StrMethodFormatter
)

dfn, dfd = 999, 9
f_sample = 13.817
alpha = [0.05, 0.025, f.sf(f_sample, dfn, dfd), 0.01, 0.005, 0.0025, 0.001]
df = pd.DataFrame(
    alpha, 
    columns=["Significance level"]
)
df["Critical value"] = df["Significance level"].apply(
    lambda x: f"{f.ppf(x, dfn, dfd):.4f}"
)
df["Type II Error for s = 2\u03C3"] = df["Critical value"].apply(
    lambda x: f"{f.cdf(float(x)/4, dfn, dfd):.4f}"
)
df["Emphasis on sample variance"] = df["Critical value"].apply(
    lambda x: f"{1/float(x):.2%} of \u03C3^2"
)
df["Emphasis on sample standard deviation"] = df["Critical value"].apply(
    lambda x: f"{1/(float(x) ** .5):.2%} of \u03C3"
)
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
x = np.linspace(
    f.ppf(0.00, dfn, dfd),
    f.ppf(0.995, dfn, dfd), 
    100
)
y = f.pdf(x, dfn, dfd)
ax.plot(x, y, 'r-', lw=4, alpha=0.6, label='f pdf')
alpha = f.ppf(1-.05, dfn, dfd)
ax.vlines(alpha, 0, f.pdf(alpha, dfn, dfd), colors='r', lw=2, alpha=0.6, label='_f_0.05')
ax.vlines(1, 0, f.pdf(1, dfn, dfd), colors='r', ls='--', lw=2, alpha=0.6, label='_f_0.05')
ax.fill_between(np.arange(alpha, x[-1], .1), f.pdf(np.arange(alpha, x[-1], .1), dfn, dfd), color='r', alpha=0.2)
ax.fill_between(np.arange(1, alpha, .1), f.pdf(np.arange(1, alpha, .1), dfn, dfd), color='g', alpha=0.1)
ax.fill_between(np.arange(0, 1.1, .1), f.pdf(np.arange(0, 1.1, .1), dfn, dfd), color='b', alpha=0.1)
ax.annotate(
    fr"$(f_{{critical}}={alpha:.5g}, \alpha=0.05, \beta=0.95)$", 
    xy=(alpha, 0.05),  
    xycoords='data',
    xytext=(alpha * 0.85, 0.15), 
    textcoords='data',
    fontsize=12
)
ax.annotate(
    fr"$(f_0=1, \alpha={f.sf(1, dfn, dfd):.5g}, \beta={f.cdf(1, dfn, dfd):.5g})$", 
    xy=(1, .9),  
    xycoords='data',
    xytext=(0.85, 0.95), 
    textcoords='data',
    fontsize=12
)
ax.annotate(
    '$H_a$', 
    xy=(.7, y.max() / 2),  
    xycoords='data',
    xytext=(1.5, .75), 
    textcoords='data',
    arrowprops=dict(facecolor='b', edgecolor='b', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="b")
)
ax.annotate(
    '$H_0$', 
    xy=(1.2, y.max() / 4),  
    xycoords='data',
    xytext=(2.5, .7), 
    textcoords='data',
    arrowprops=dict(facecolor='g', edgecolor='g', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="g")
)
ax.arrow(1.05, .025, alpha - 1.2,  0, width=.005, head_width=.025, head_length=.1, fc='r', ec='r', alpha=.6)
ax.set_title(f'Probability densitity function for $f \sim F(999,9)$', fontsize=16)
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:.0%}'))
ax.xaxis.set_minor_locator(MultipleLocator(.25))
ax.set(xlim=(0, x[-1]), ylim=(0, 1), autoscale_on=False)
ax.set_xlabel('F-test-statistic $f$', fontsize=14)
ax.set_ylabel('Probability density', fontsize=14)
fig.tight_layout()
fig.savefig("4.svg", bbox_inches="tight")
plt.show()
df
# Out:
#    Significance level Critical value Type II Error for s = 2σ  \
# 0            0.050000         0.5293                   0.0000
# 1            0.025000         0.4703                   0.0000
# 2            0.000095         0.2624                   0.0000
# 3            0.010000         0.4124                   0.0000
# 4            0.005000         0.3784                   0.0000
# 5            0.002500         0.3502                   0.0000
# 6            0.001000         0.3195                   0.0000
#
#   Emphasis on sample variance Emphasis on sample standard deviation
# 0              188.93% of σ^2                          137.45% of σ
# 1              212.63% of σ^2                          145.82% of σ
# 2              381.10% of σ^2                          195.22% of σ
# 3              242.48% of σ^2                          155.72% of σ
# 4              264.27% of σ^2                          162.56% of σ
# ...

# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, StrMethodFormatter

dfn, dfd = 999, 9
f_sample = 13.817
alpha = [0.05, 0.025, stats.f.sf(f_sample, dfn, dfd), 0.01, 0.005, 0.0025, 0.001]

fig, ax = plt.subplots(1, 1, figsize=(10, 6))
x = np.linspace(
    stats.f.ppf(0.001, dfn, dfd),
    stats.f.ppf(0.999, dfn, dfd),
    1000
)
y = stats.f.pdf(x, dfn, dfd)
ax.plot(x, y, 'r-', lw=2, alpha=0.6, label='f pdf')

# Left-tail critical value
alpha_critical = stats.f.ppf(0.05, dfn, dfd)
ax.vlines(alpha_critical, 0, stats.f.pdf(alpha_critical, dfn, dfd), colors='r', lw=2, alpha=0.6, label='_f_0.05')

# Fill Ha area
ax.fill_between(x, y, where=(x < alpha_critical), color='r', alpha=0.1)

# Ha arrow
ax.annotate(
    '$H_a$', 
    xy=(alpha_critical - 0.2, 0.025),  
    xycoords='data',
    xytext=(alpha_critical - 1, 0.05), 
    textcoords='data',
    arrowprops=dict(facecolor='r', edgecolor='r', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="r")
)

# Right-tail critical value
#alpha_critical_right = stats.f.ppf(0.95, dfn, dfd)
ax.vlines(alpha_critical_right, 0, stats.f.pdf(alpha_critical_right, dfn, dfd), colors='g', lw=2, alpha=0.6, label='_f_0.05')

# Fill H0 area
ax.fill_between(x, y, where=(x > alpha_critical_right), color='g', alpha=0.1)

# H0 arrow
ax.annotate(
    '$H_0$', 
    xy=(alpha_critical_right + 0.2, 0.025),  
    xycoords='data',
    xytext=(alpha_critical_right + 1, 0.05), 
    textcoords='data',
    arrowprops=dict(facecolor='g', edgecolor='g', width=1, headwidth=8, alpha=.6),
    horizontalalignment='left', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="g")
)

ax.set_title(f'Probability density function for $f \sim F(999,9)$', fontsize=16)
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:.0%}'))
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.set(xlim=(0, x[-1]), ylim=(0, 0.25), autoscale_on=False)
ax.set_xlabel('F-test statistic', fontsize=14)
ax.set_ylabel('Probability density', fontsize=14)

plt.show()

# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, StrMethodFormatter

dfn, dfd = 999, 9
f_sample = 0.0723
alpha = [0.05, 0.025, stats.f.sf(f_sample, dfn, dfd), 0.01, 0.005, 0.0025, 0.001]

fig, ax = plt.subplots(1, 1, figsize=(10, 6))
x = np.linspace(
    stats.f.ppf(0.001, dfn, dfd),
    stats.f.ppf(0.999, dfn, dfd),
    1000
)
y = stats.f.pdf(x, dfn, dfd)
ax.plot(x, y, 'r-', lw=2, alpha=0.6, label='f pdf')

# Left-tail critical value
alpha_critical = stats.f.ppf(0.05, dfn, dfd)
ax.vlines(alpha_critical, 0, stats.f.pdf(alpha_critical, dfn, dfd), colors='r', lw=2, alpha=0.6, label='_f_0.05')

# Fill Ha area
ax.fill_between(x, y, where=(x < alpha_critical), color='r', alpha=0.1)

# Ha arrow
ax.annotate(
    '$H_a$', 
    xy=(alpha_critical - 0.1, 0.025),  
    xycoords='data',
    xytext=( 1, 0.15), 
    textcoords='data',
    arrowprops=dict(facecolor='r', edgecolor='r', width=1, headwidth=8, alpha=.6),
    horizontalalignment='right', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="r")
)

# H0 arrow
ax.annotate(
    '$H_0$', 
    xy=( 0.8, 0.25),  
    xycoords='data',
    xytext=( 1, 0.45), 
    textcoords='data',
    arrowprops=dict(facecolor='b', edgecolor='b', width=1, headwidth=8, alpha=.6),
    horizontalalignment='left', 
    verticalalignment='top',
    fontsize=14,
    bbox=dict(boxstyle="round", facecolor="w", edgecolor="b")
)


ax.set_title(f'Probability density function for $f \sim F(999,9)$', fontsize=16)
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:.0%}'))
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.set(xlim=(0, x[-1]), ylim=(0, 1), autoscale_on=False)
ax.set_xlabel('F-test statistic', fontsize=14)
ax.set_ylabel('Probability density', fontsize=14)
import scipy.stats as stats

dfn = 999
dfd = 9
alpha = 0.05



dfn, dfd = 999, 9
alpha = 0.05

f_critical = stats.f.ppf(alpha, dfn, dfd)
print(f"F critical value: {f_critical:.4f}")

plt.show()
# Out:
# F critical value: 0.5293

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define degrees of freedom
df1 = 9  # Numerator degrees of freedom
df2 = 999  # Denominator degrees of freedom

# Generate x values for plotting
x = np.linspace(0, 5, 500)

# Compute the F-distribution for the given degrees of freedom
f_dist = stats.f(df1, df2)

# Compute the critical F-value at alpha level 0.05
alpha = 0.05
f_critical = f_dist.ppf(alpha)

# Plot the F-distribution
plt.plot(x, f_dist.pdf(x), label=f"F-distribution (df1={df1}, df2={df2})")
plt.fill_between(x, 0, f_dist.pdf(x), where=x <= f_critical, alpha=0.3, color='red', label='Rejection Region')
plt.axvline(f_critical, color='red', linestyle='--', label='Critical F-value')
plt.legend()

# Add labels and title
plt.xlabel('F-statistic')
plt.ylabel('Probability Density')
plt.title('F-Distribution for Hypothesis Testing')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define degrees of freedom
df1 = 999  # Numerator degrees of freedom
df2 = 9  # Denominator degrees of freedom

# Generate x values for plotting
x = np.linspace(0, 5, 500)

# Compute the F-distribution for the given degrees of freedom
f_dist = stats.f(df1, df2)

# Compute the critical F-value at alpha level 0.05 (left-tailed)
alpha = 0.05
f_critical = f_dist.ppf(1 - alpha)

# Compute the F-statistic from your hypothesis test
f_test = 0.072

# Plot the F-distribution
plt.plot(x, f_dist.pdf(x), label=f"F-distribution (df1={df1}, df2={df2})")
plt.fill_between(x, 0, f_dist.pdf(x), where=x <= f_critical, alpha=0.3, color='red', label='Rejection Region')
plt.axvline(f_critical, color='red', linestyle='--', label='Critical F-value')
plt.axvline(f_test, color='green', linestyle='--', label='F-statistic')
plt.legend()

# Add labels and title
plt.xlabel('F-statistic')
plt.ylabel('Probability Density')
plt.title('F-Distribution for Hypothesis Testing', fontsize=14)

# Print the critical F-value and F-test value
print("Critical F-value:", f_critical)
print("F-test value:", f_test)

# Show the plot
plt.show()
# Out:
# Critical F-value: 2.7116445979050603
# F-test value: 0.072

# %%
import scipy.stats as stats

# Define degrees of freedom
df1 = 999  # Numerator degrees of freedom
df2 = 9  # Denominator degrees of freedom

# Compute the F-distribution value
f_value = stats.f.ppf(0.05, df1, df2)

# Print the F-distribution value
print("F(0.95, 999, 9) =", f_value)
# Out:
# F(0.95, 999, 9) = 0.529314555554733

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define degrees of freedom
df1 = 999  # Numerator degrees of freedom
df2 = 9  # Denominator degrees of freedom

# Generate x values for plotting
x = np.linspace(0, 7, 1000)

# Compute the F-distribution for the given degrees of freedom
f_dist = stats.f(df1, df2)

# Compute the critical F-value at alpha level 0.05 (left-tailed)
alpha = 0.05
f_critical = f_dist.ppf(alpha)

# Compute the F-statistic from your hypothesis test
f_test = 0.07237528

# Calculate the p-value for left-tailed test
p_value = f_dist.cdf(f_test)

# Plot the F-distribution
plt.plot(x, f_dist.pdf(x), label=f"F-distribution (df1={df1}, df2={df2})")
plt.fill_between(x, 0, f_dist.pdf(x), where=x <= f_critical, alpha=0.8, color='red', label='H0: F >= f_critical')
plt.fill_between(x, 0, f_dist.pdf(x), where=x >= f_critical, alpha=0.8, color='green', label='Ha: F < f_critical')
plt.axvline(f_critical, color='red', linestyle='--', label='Critical F-value')
plt.axvline(f_test, color='blue', linestyle='--', label='F-statistic')
plt.legend()

# Add labels and title
plt.xlabel('F test statistic f', fontsize=14)
plt.ylabel('Probability Density', fontsize=14)
plt.title('F-Distribution Left-Tailed Hypothesis Testing', fontsize=14)

# Print the critical F-value, F-test value, and p-value
print("Critical F-value:", f_critical)
print("F-test value:", f_test)
print("p-value:", p_value)

# Show the plot
plt.show()
# Out:
# Critical F-value: 0.529314555554733
# F-test value: 0.07237528
# p-value: 4.1260759745662e-21

# %%
from scipy.stats import f

alpha = 0.05  # Significance level
df1 = 999       # Degrees of freedom for numerator
df2 = 9      # Degrees of freedom for denominator

# Calculate the critical F-value
critical_f_value = f.ppf(alpha, df1, df2)
f_stat = 0.07237528

# Calculate the p-value
p_value = f.cdf(f_stat, df1, df2)

print("Critical F-value:", critical_f_value)
print("P-value:", p_value)
# Out:
# Critical F-value: 0.529314555554733
# P-value: 4.1260759745662e-21

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define degrees of freedom
df1 = 999  # Numerator degrees of freedom
df2 = 9  # Denominator degrees of freedom

# Generate x values for plotting
x = np.linspace(0, 5, 500)

# Compute the F-distribution for the given degrees of freedom
f_dist = stats.f(df1, df2)

# Compute the critical F-value at alpha level 0.05 (left-tailed)
alpha = 0.05
f_critical = f_dist.ppf(alpha)

# Compute the F-statistic from your hypothesis test
f_test = 0.072

# Calculate the p-value for left-tailed test
p_value = f_dist.cdf(f_test)

# Plot the F-distribution
plt.plot(x, f_dist.pdf(x), label=f"F-distribution (df1={df1}, df2={df2})")
plt.fill_between(x, 0, f_dist.pdf(x), where=x <= f_critical, alpha=0.3, color='red', label='H0: F-statistic >= f_critical')
plt.fill_between(x, 0, f_dist.pdf(x), where=x < f_test, alpha=0.3, color='blue', label='Ha: F-statistic < f_critical')
plt.axvline(f_critical, color='red', linestyle='--', label='Critical F-value')
plt.axvline(f_test, color='green', linestyle='--', label='F-statistic')
plt.legend()

# Add labels and title
plt.xlabel('F-statistic')
plt.ylabel('Probability Density')
plt.title('F-Distribution for Hypothesis Testing')

# Print the critical F-value, F-test value, and p-value
print("Critical F-value:", f_critical)
print("F-test value:", f_test)
print("p-value:", p_value)

# Show the plot
plt.show()
# Out:
# Critical F-value: 0.529314555554733
# F-test value: 0.072
# p-value: 3.142717511286465e-21

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define degrees of freedom
df1 = 999  # Numerator degrees of freedom
df2 = 9  # Denominator degrees of freedom

# Generate x values for plotting
x = np.linspace(0, 7, 1000)

# Compute the F-distribution for the given degrees of freedom
f_dist = stats.f(df1, df2)

# Compute the critical F-value at alpha level 0.05 (left-tailed)
alpha = 0.05
f_critical = f_dist.ppf(alpha)

# Compute the F-statistic from your hypothesis test
f_test = 0.07237528

# Calculate the p-value for left-tailed test
p_value = f_dist.cdf(f_test)

# Plot the F-distribution
plt.plot(x, f_dist.pdf(x), label=f"F-distribution (df1={df1}, df2={df2})")
plt.fill_between(x, 0, f_dist.pdf(x), where=x <= f_critical, alpha=0.8, color='red', label='H0: F >= f_critical')
plt.fill_between(x, 0, f_dist.pdf(x), where=x >= f_critical, alpha=0.8, color='green', label='Ha: F < f_critical')
plt.axvline(f_critical, color='red', linestyle='--', label='Critical F-value')
plt.axvline(f_test, color='blue', linestyle='--', label='F-statistic')
plt.legend()

# Add labels and title
plt.xlabel('F test statistic f', fontsize=14)
plt.ylabel('Probability Density', fontsize=14)
plt.title('F-Distribution Left-Tailed Hypothesis Testing', fontsize=14)

# Print the critical F-value, F-test value, and p-value
print("Critical F-value:", f_critical)
print("F-test value:", f_test)
print("p-value:", p_value)

# Check if H0 should be rejected
if f_test < f_critical:
    print("F-statistic < Critical F-value => Reject the null hypothesis H0 and accept Ha ")
else:
    print("F-statistic >= Critical F-value => Failed to reject H0 ")

# Check if H0 should be rejected based on p-value
if p_value < alpha:
    print("P-value < Level of Significance => Reject the null hypothesis H0 and accept Ha")
else:
    print("P-value >= Level of Significance alpha Failed to reject H0")

# Show the plot
plt.show()
# Out:
# Critical F-value: 0.529314555554733
# F-test value: 0.07237528
# p-value: 4.1260759745662e-21
# F-statistic < Critical F-value => Reject the null hypothesis H0 and accept Ha
# P-value < Level of Significance => Reject the null hypothesis H0 and accept Ha

# %%
import numpy as np
from tabulate import tabulate
import scipy.stats as stats

# Define degrees of freedom
df1 = 999  # Numerator degrees of freedom
df2 = 9  # Denominator degrees of freedom

# Generate x values for plotting
x = np.linspace(0, 7, 1000)

# Compute the F-distribution for the given degrees of freedom
f_dist = stats.f(df1, df2)

# Define alpha levels
alpha_levels = [0.1, 0.05, 0.025, 0.01, 0.005, 0.0025, 0.001]

# Create an empty table
results_table = []

# Iterate over alpha levels
for alpha in alpha_levels:
    # Compute the critical F-value at the current alpha level (left-tailed)
    f_critical = f_dist.ppf(alpha)
    
    # Generate a random F-test value (replace this with your own F-test value)
    f_test = 0.07237528
    
    # Calculate the p-value for left-tailed test
    p_value = f_dist.cdf(f_test)
    
    # Check if H0 should be rejected based on the F-statistic and the critical F-value
    if f_test < f_critical:
        reject_h0 = 'Yes'
    else:
        reject_h0 = 'No'
    
    # Add the results to the table
    results_table.append([alpha, f_critical, f_test, reject_h0])

# Print the results table
table_headers = ['Alpha', 'Critical F-value', 'F-test value', 'Reject H0']
table_string = tabulate(results_table, headers=table_headers, tablefmt='grid')

print(table_string)
# Out:
# +---------+--------------------+----------------+-------------+
# |   Alpha |   Critical F-value |   F-test value | Reject H0   |
# +=========+====================+================+=============+
# |  0.1    |           0.610576 |      0.0723753 | Yes         |
# +---------+--------------------+----------------+-------------+
# |  0.05   |           0.529315 |      0.0723753 | Yes         |
# +---------+--------------------+----------------+-------------+
# |  0.025  |           0.47028  |      0.0723753 | Yes         |
# +---------+--------------------+----------------+-------------+
# |  0.01   |           0.412361 |      0.0723753 | Yes         |
# +---------+--------------------+----------------+-------------+
# |  0.005  |           0.378374 |      0.0723753 | Yes         |
# +---------+--------------------+----------------+-------------+
# |  0.0025 |           0.35021  |      0.0723753 | Yes         |
# +---------+--------------------+----------------+-------------+
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define degrees of freedom
df1 = 999  # Numerator degrees of freedom
df2 = 9  # Denominator degrees of freedom

# Generate x values for plotting
x = np.linspace(0, 7, 1000)

# Compute the F-distribution for the given degrees of freedom
f_dist = stats.f(df1, df2)

# Compute the critical F-value at alpha level 0.05 (left-tailed)
alpha = 0.05
f_critical = f_dist.ppf(alpha)

# Compute the F-statistic from your hypothesis test
f_test = 0.07237528

# Calculate the p-value for left-tailed test
p_value = f_dist.cdf(f_test)

# Plot the F-distribution
plt.figure(figsize=(10, 6))  # Enlarge the plot size
plt.plot(x, f_dist.pdf(x), label=f"F-distribution (df1={df1}, df2={df2})")
plt.fill_between(x, 0, f_dist.pdf(x), where=x <= f_critical, alpha=0.5, color='green', label='Ha: F < f_critical')
plt.fill_between(x, 0, f_dist.pdf(x), where=x >= f_critical, alpha=0.5, color='red', label='H0: F >= f_critical')
plt.axvline(f_critical, color='red', linestyle='--', label='Critical F-value')
plt.axvline(f_test, color='blue', linestyle='--', label='F-statistic')

# Annotate the regions of H0 and Ha
plt.text(0.3, 0.05, 'Ha', fontsize=12, fontweight='bold', color='black', ha='center')
plt.text(5.5, 0.05, 'H0', fontsize=12, fontweight='bold', color='black', ha='center')

plt.legend()

# Add labels and title
plt.xlabel('F test statistic f', fontsize=14)
plt.ylabel('Probability Density', fontsize=14)
plt.title('F-Distribution Left-Tailed Hypothesis Testing', fontsize=14)

# Print the critical F-value, F-test value, and p-value
print("Critical F-value:", f_critical)
print("F-test value:", f_test)
print("p-value:", p_value)

# Check if H0 should be rejected based on the F-statistic
if f_test < f_critical:
    print("F-statistic < Critical F-value => Reject the null hypothesis H0 and accept Ha")
else:
    print("F-statistic >= Critical F-value => Failed to reject H0")

# Check if H0 should be rejected based on the p-value
if p_value < alpha:
    print("P-value < Level of Significance => Reject the null hypothesis H0 and accept Ha")
else:
    print("P-value >= Level of Significance alpha => Failed to reject H0")

# Annotate F critical value
plt.annotate(f'F critical: {f_critical:.4f}', xy=(f_critical, 0.02), xytext=(f_critical, 0.2),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
# Show the plot
plt.show()
# Out:
# Critical F-value: 0.529314555554733
# F-test value: 0.07237528
# p-value: 4.1260759745662e-21
# F-statistic < Critical F-value => Reject the null hypothesis H0 and accept Ha
# P-value < Level of Significance => Reject the null hypothesis H0 and accept Ha

# %%
# Plot the F-distribution
plt.figure(figsize=(10, 6))  # Enlarge the plot size
# Plot the F-distribution
plt.plot(x, f_dist.pdf(x), label=f"F-distribution (df1={df1}, df2={df2})")
plt.fill_between(x, 0, f_dist.pdf(x), where=x <= f_critical, alpha=0.8, color='red', label='H0: F >= f_critical')
plt.fill_between(x, 0, f_dist.pdf(x), where=x >= f_critical, alpha=0.8, color='green', label='Ha: F < f_critical')
plt.axvline(f_critical, color='red', linestyle='--', label='Critical F-value')
plt.axvline(f_test, color='blue', linestyle='--', label='F-statistic')

# Annotate F critical value
plt.annotate(f'F critical: {f_critical:.4f}', xy=(f_critical, 0.02), xytext=(f_critical, 0.2),
             arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.legend()
plt.xlabel('F test statistic f', fontsize=14)
plt.ylabel('Probability Density', fontsize=14)
plt.title('F-Distribution Left-Tailed Hypothesis Testing', fontsize=14)

plt.show()
